# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pls
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings('ignore')

# %%
books = pd.read_csv('/content/Books.csv')
ratings = pd.read_csv('/content/Ratings.csv')
users = pd.read_csv('/content/Users.csv')

# %%
books.head()
# Out:
#          ISBN  ...                                        Image-URL-L
# 0  0195153448  ...  http://images.amazon.com/images/P/0195153448.0...
# 1  0002005018  ...  http://images.amazon.com/images/P/0002005018.0...
# 2  0060973129  ...  http://images.amazon.com/images/P/0060973129.0...
# 3  0374157065  ...  http://images.amazon.com/images/P/0374157065.0...
# 4  0393045218  ...  http://images.amazon.com/images/P/0393045218.0...
#
# [5 rows x 8 columns]

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
print("Books shape :",books.shape)
print("Ratings shape :",ratings.shape)
print("Users shape :",users.shape)
# Out:
# Books shape : (271360, 8)
# Ratings shape : (1149780, 3)
# Users shape : (278858, 3)

# %%
books.isna().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
books.dropna(inplace=True)

# %%
ratings.isna().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
users.isna().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings['Book-Rating'].value_counts()
# Out:
# Book-Rating
# 0     716109
# 8     103736
# 10     78610
# 7      76457
# 9      67541
# 5      50974
# 6      36924
# 4       8904
# 3       5996
# 2       2759
# 1       1770
# Name: count, dtype: int64

# %%
ratings_cleaned = ratings[ratings['Book-Rating'] != 0]

# %%
sns.histplot(ratings_cleaned['Book-Rating'],bins=10,kde=True)
# Out:
# <Axes: xlabel='Book-Rating', ylabel='Count'>

# %%
ratings_cleaned['Book-Rating'].value_counts()
# Out:
# Book-Rating
# 8     103736
# 10     78610
# 7      76457
# 9      67541
# 5      50974
# 6      36924
# 4       8904
# 3       5996
# 2       2759
# 1       1770
# Name: count, dtype: int64

# %%
ratings_cleaned.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 1   276726  0155061224            5
# 3   276729  052165615X            3
# 4   276729  0521795028            6
# 6   276736  3257224281            8
# 7   276737  0600570967            6

# %%
ratings_with_name = ratings_cleaned.merge(books,on='ISBN')

# %%
ratings_with_name.head()
# Out:
#    User-ID  ...                                        Image-URL-L
# 0   276726  ...  http://images.amazon.com/images/P/0155061224.0...
# 1   276729  ...  http://images.amazon.com/images/P/052165615X.0...
# 2   276729  ...  http://images.amazon.com/images/P/0521795028.0...
# 3   276744  ...  http://images.amazon.com/images/P/038550120X.0...
# 4   276747  ...  http://images.amazon.com/images/P/0060517794.0...
#
# [5 rows x 10 columns]

# %%
num_ratings_book = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_ratings_book.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_ratings_book.head()
# Out:
#                                           Book-Title  num_ratings
# 0   A Light in the Storm: The Civil War Diary of ...            1
# 1   Ask Lily (Young Women of Faith: Lily Series, ...            1
# 2                                       Dark Justice            1
# 3   Earth Prayers From around the World: 365 Pray...            7
# 4   Final Fantasy Anthology: Official Strategy Gu...            2

# %% [markdown]
# ##Collaborative Filtering System

# %%
x = ratings_with_name.groupby('User-ID').count() > 50
regular_users = x[x].index

# %%
regular_users
# Out:
# Index([     8,      9,     12,     14,     16,     17,     19,     22,     26,
#            32,
#        ...
#        278831, 278832, 278836, 278843, 278844, 278846, 278849, 278851, 278852,
#        278854],
#       dtype='int64', name='User-ID', length=68091)

# %%
filtered_ratings = ratings_with_name[ratings_with_name["User-ID"].isin(regular_users)]
filtered_ratings.head()
# Out:
#    User-ID  ...                                        Image-URL-L
# 0   276726  ...  http://images.amazon.com/images/P/0155061224.0...
# 1   276729  ...  http://images.amazon.com/images/P/052165615X.0...
# 2   276729  ...  http://images.amazon.com/images/P/0521795028.0...
# 3   276744  ...  http://images.amazon.com/images/P/038550120X.0...
# 4   276747  ...  http://images.amazon.com/images/P/0060517794.0...
#
# [5 rows x 10 columns]

# %%
y = filtered_ratings.groupby("Book-Title").count()["Book-Rating"]>=30
famous_books = y[y].index

# %%
final_ratings = filtered_ratings[filtered_ratings['Book-Title'].isin(famous_books)]

# %%
final_ratings.head()
# Out:
#     User-ID  ...                                        Image-URL-L
# 3    276744  ...  http://images.amazon.com/images/P/038550120X.0...
# 4    276747  ...  http://images.amazon.com/images/P/0060517794.0...
# 5    276747  ...  http://images.amazon.com/images/P/0671537458.0...
# 11   276754  ...  http://images.amazon.com/images/P/0684867621.0...
# 12   276755  ...  http://images.amazon.com/images/P/0451166892.0...
#
# [5 rows x 10 columns]

# %%
pt = final_ratings.pivot_table(index="Book-Title", columns = "User-ID", values = "Book-Rating")

# %%
pt
# Out:
# User-ID                                             9       ...  278854
# Book-Title                                                  ...
# 1984                                                   NaN  ...     NaN
# 1st to Die: A Novel                                    NaN  ...     NaN
# 2010: Odyssey Two                                      NaN  ...     NaN
# 24 Hours                                               NaN  ...     NaN
# 2nd Chance                                             NaN  ...     NaN
# ...                                                    ...  ...     ...
# Wuthering Heights (Penguin Classics)                   NaN  ...     NaN
# Year of Wonders                                        NaN  ...     NaN
# You Belong To Me                                       NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# [1324 rows x 30350 columns]

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             9       ...  278854
# Book-Title                                                  ...
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2010: Odyssey Two                                      0.0  ...     0.0
# 24 Hours                                               0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# ...                                                    ...  ...     ...
# Wuthering Heights (Penguin Classics)                   0.0  ...     0.0
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# [1324 rows x 30350 columns]

# %%
similarity_score = cosine_similarity(pt)

# %%
def recommend(book_name):
  index = np.where(pt.index==book_name)[0][0]
  similar_items = sorted(list(enumerate(similarity_score[index])), key=lambda x:x[1], reverse=True)[1:6]


  data = []
  for i in similar_items:
      item = []
      temp_df = books[books['Book-Title'] == pt.index[i[0]]]
      item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
      item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
      item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

      data.append(item)

  return data

# %%
recommend("Harry Potter and the Prisoner of Azkaban (Book 3)")
# Out:
# [['Harry Potter and the Goblet of Fire (Book 4)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439139597.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Chamber of Secrets (Book 2)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439064872.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Book 1)",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Order of the Phoenix (Book 5)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/059035342X.01.MZZZZZZZ.jpg']]
